# %%
print("Welcome to your new notebook")
# Out:
# StatementMeta(, 2a3609a6-ccfd-4599-a6e8-b86830645010, 4, Finished, Available, Finished)
# Welcome to your new notebook

# %% [markdown]
# # **Data Engineering**

# %%
df = spark.read.format("csv").option("header","true").load("Files/Adls/Returns.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Adls/Returns.csv".
display(df)
# Out:
# StatementMeta(, 2a3609a6-ccfd-4599-a6e8-b86830645010, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6d5c8c95-19c4-4d97-935a-2d6ba359546b)

# %%
abfss://d4759ed9-e0be-4822-90e8-1e0f8e67de08@onelake.dfs.fabric.microsoft.com/c7ce1fe0-b5f4-4568-b02b-6c6bf105f878/Files/Adls/Returns.csv

# %%
df = spark.read.option("multiline", "true").json("Tables/Dataflow/_delta_log/00000000000000000002.json")
# df now is a Spark DataFrame containing JSON data from "Tables/Dataflow/_delta_log/00000000000000000002.json".
display(df)
# Out:
# StatementMeta(, 2a3609a6-ccfd-4599-a6e8-b86830645010, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 8a8c1ea9-0d5e-4263-9478-942bc5108ebc)
